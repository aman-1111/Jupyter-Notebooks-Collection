# %%
import seaborn as sns 
import pandas as pd
import matplotlib.pyplot as plt
from math import sqrt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
df=pd.read_csv("FyntraCustomerData.csv")
df
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %%
sns.pairplot(df)
# Out:
# /home/aman-chaurasia/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/aman-chaurasia/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/aman-chaurasia/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
df.corr(numeric_only="TRUE")

# %%
sns.heatmap(df.corr(numeric_only="TRUE"),cmap="coolwarm",annot=True)

# %% [markdown]
# 1. Compute -- Use seaborn to create a jointplot to compare the Time on
# Website and Yearly Amount Spent columns. Is there a correlation?

# %%
sns.jointplot(data=df,x="Time_on_Website",y="Yearly_Amount_Spent")
# Out:
# /home/aman-chaurasia/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/aman-chaurasia/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.jointplot(data=df,x="Avg_Session_Length",y="Length_of_Membership")

# %% [markdown]
# 2. Compute – Do the same as above but now with Time on App and Yearly
# Amount Spent. Is this correlation stronger than 1st One?

# %%
df_Time_web_Amount= df.filter({"Time_on_Website","Yearly_Amount_Spent"})
sns.set(style="darkgrid",color_codes=True)
sns.color_palette()
sns.jointplot(x="Time_on_Website",y="Yearly_Amount_Spent",data=df_Time_web_Amount)
# Out:
# /home/aman-chaurasia/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/aman-chaurasia/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Compute -- Explore types of relationships across the entire data set using
# pairplot . Based off this plot what looks to be the most correlated feature
# with Yearly Amount Spent?

# %%
coff_Time_web_Amount=df_Time_web_Amount.corr()
sns.heatmap(coff_Time_web_Amount)
sns.pairplot(coff_Time_web_Amount)
# Out:
# /home/aman-chaurasia/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/aman-chaurasia/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
x=df["Length_of_Membership"]
y=df["Yearly_Amount_Spent"]

# %%
x
# Out:
# 0      4.082621
# 1      2.664034
# 2      4.104543
# 3      3.120179
# 4      4.446308
#          ...
# 495    3.746573
# 496    3.576526
# 497    4.958264
# 498    2.336485
# 499    2.735160
# Name: Length_of_Membership, Length: 500, dtype: float64

# %%
y

# %%
type(y)

# %%
train_x

# %% [markdown]
# **X is a feature and y is a target**

# %%
train_y

# %% [markdown]
# Compute – Train and Test the data and answer multiple questions -- What
# is the use of random_state=85?

# %%
train_x,test_x,train_y,test_y=train_test_split(x,y,random_state=85,test_size=0.3)

# %% [markdown]
# 4. Compute – Create linear model plot of Length of Membership and Yearly
# Amount Spent. Does the data fits well in linear plot?

# %%
lin_model = LinearRegression()   
lin_model.fit(pd.DataFrame(train_x),train_y)
# Out:
# LinearRegression()

# %% [markdown]
# 6. Compute – Predict the data and do a scatter plot. Check if actual and
# predicted data match?

# %%
predicted_values=lin_model.predict(pd.DataFrame(test_x))
plt.scatter(predicted_values,test_y)
plt.show()

# %% [markdown]
# What is the value of Root Mean Squared Error?

# %%
mse = mean_squared_error(predicted_values,test_y)
mse
# Out:
# 2005.008450066019

# %%
rmse=mse
rmse
# Out:
# 2005.008450066019

# %%
sns.jointplot(x="Time_on_Website",y="Yearly_Amount_Spent",data=df,kind="scatter")
plt.show()
